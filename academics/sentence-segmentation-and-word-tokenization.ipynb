# %%
text = "I am a student of Dahanukar College"
tokens = text.split()
tokens
# Out:
# ['I', 'am', 'a', 'student', 'of', 'Dahanukar', 'College']

# %% [markdown]
# ### sentence tokenization

# %%
import nltk
from nltk.tokenize import sent_tokenize
# nltk.download('punkt')
text = "I am a student of Dahanukar College. It was established in 1670. I am studing in tyds. My roll no is 69. My fav teacher is amit bane."
tokens = sent_tokenize(text)
tokens
# Out:
# ['I am a student of Dahanukar College.',
#  'It was established in 1670.',
#  'I am studing in tyds.',
#  'My roll no is 69.',
#  'My fav teacher is amit bane.']

# %% [markdown]
# ### word tokenization

# %%
import nltk
from nltk.tokenize import word_tokenize
# nltk.download('punkt')
text = "I am a student of Dahanukar College. It was established in 1670. I am studing in tyds. My roll no is 69. My fav teacher is amit bane."
tokens = word_tokenize(text)
tokens
# Out:
# ['I',
#  'am',
#  'a',
#  'student',
#  'of',
#  'Dahanukar',
#  'College',
#  '.',
#  'It',
#  'was',
#  'established',
#  'in',
#  '1670',
#  '.',
#  'I',
#  'am',
#  'studing',
#  'in',
#  'tyds',
#  '.',
#  'My',
#  'roll',
#  'no',
#  'is',
#  '69',
#  '.',
#  'My',
#  'fav',
#  'teacher',
#  'is',
#  'amit',
#  'bane',
#  '.']

# %% [markdown]
# ### RegEx tokenization

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r"\w+")
text = "Let's see how it's working."
tokenizer.tokenize(text)
# Out:
# ['Let', 's', 'see', 'how', 'it', 's', 'working']

# %% [markdown]
# ### TreebankWordTokenizer

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize("Let's see how it's working.")
# Out:
# ['Let', "'s", 'see', 'how', 'it', "'s", 'working', '.']
